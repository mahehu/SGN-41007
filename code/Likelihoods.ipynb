# %% [markdown]
# # Plot a likelihood and a log-likelihood function

# %% [markdown]
# Example of plotting two functions in the same plot (with double y-axis).

# %% [markdown]
# Imports:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Define our Gaussian and log-of-Gaussian functions:

# %%
def gaussian(x, mu, sig):
    Z = (1/np.sqrt(2*np.pi*sig**2.))
    return Z * np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

def gaussian_log(x, mu, sig):
    Z = (1/np.sqrt(2*np.pi*sig**2.))
    return np.log(Z) + (-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

# %% [markdown]
# Finally, plot the two functions:

# %%
x = np.linspace(-3, 9, 100)
y1 = gaussian(x, 3, 1)

ax1 = plt.subplot(211)
p1 = plt.plot(x, y1, 'B', linewidth = 2, label = "Likelihood")
ax1.set_xlabel('A')
ax1.set_title('PDF of A assuming x[0] = 3')

for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
p2 = plt.plot(x, gaussian_log(x, 3, 1), 'r', linewidth = 2, label = "Log-likelihood")
   
for tl in ax2.get_yticklabels():
    tl.set_color('r')

lns = p1 + p2
labs = [l.get_label() for l in lns]
ax2.legend(lns, labs, loc=1)
plt.show()
